# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("static/data/agriRuralDevelopment_clean.csv")
df.head()
# Out:
#           Name Code  Year  Access to electricity (% of population)  \
# 0  Afghanistan  AFG  1960                                     23.0
# 1  Afghanistan  AFG  1961                                     23.0
# 2  Afghanistan  AFG  1962                                     23.0
# 3  Afghanistan  AFG  1963                                     23.0
# 4  Afghanistan  AFG  1964                                     23.0
#
#    Access to electricity, rural (% of rural population)  \
# 0                                           8.020724
# 1                                           8.020724
# 2                                           8.020724
# 3                                           8.020724
# 4                                           8.020724
#
#    Agricultural irrigated land (% of total agricultural land)  \
# 0                                           4.622149
# 1                                           4.622149
# 2                                           4.622149
# ...
